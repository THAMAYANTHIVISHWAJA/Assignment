# %%
#importing matplotlib for visualizing data diagramaticaly

# %%
import matplotlib.pyplot as pl
# %matplotlib inline

# %%
import numpy as np

# %%
#importing seaborn

# %%
import seaborn as sn

# %%
import pandas as pan

# %%
from bs4 import BeautifulSoup

# %%
#reading a dataset

# %%
a=pan.read_csv("C:\\Users\\aedpu\\OneDrive\\Documents\\2Bsc(cs)-Thamayanthi vishwaja\\new.csv")

# %%
a
# Out:
#                       Console                             Most Sold Game  \
# 0               PlayStation 2              Grand Theft Auto: San Andreas
# 1                 Nintendo DS                                 Nintendogs
# 2             Nintendo Switch                        Mario Kart 8 Deluxe
# 3                    Game Boy                                     Tetris
# 4              Game Boy Color    Pokemon Gold/Silver/Crystal (1999-2000)
# 5               PlayStation 4                         Grand Theft Auto V
# 6                 PlayStation                               Gran Turismo
# 7                         Wii                                 Wii Sports
# 8               PlayStation 3                         Grand Theft Auto V
# 9                    Xbox 360                         Kinect Adventures!
# 10           Game Boy Advance  Pokemon Ruby/Sapphire/Emerald (2002-2005)
# 11       PlayStation Portable     Grand Theft Auto: Liberty City Stories
# ...

# %%
pl.scatter(a['Year of Release (Game)'],a['Units Sold (in millions)'])

# %%
#barchart

# %%
pl.bar(a['Most Sold Game'],a['Units Sold (in millions)'])
# Out:
# <BarContainer object of 51 artists>

# %%
pl.plot(a['Console'],a['Year of Release (Game)'],linestyle='dotted')

# %%
b=a.tail()

# %%
b
# Out:
#          Console    Most Sold Game  Year of Release (Game)  \
# 46    Atari 7800  Pole Position II                    1983
# 47    Atari Lynx  California Games                    1989
# 48  Philips CD-i     The 7th Guest                    1993
# 49       Telstar    Telstar Arcade                    1977
# 50    Atari 5200    Super Breakout                    1982
#
#     Units Sold (in millions)       Extra Information
# 46                       1.0  1 million+ (estimated)
# 47                       0.5     500,000 (estimated)
# 48                       2.0   2 million (estimated)
# 49                       1.0  1 million+ (estimated)
# 50                       1.0  1 million+ (estimated)

# %%
pl.pie(a['Units Sold (in millions)'],labels=a['Year of Release (Game)'])
# Out:
# ([<matplotlib.patches.Wedge at 0x1b6c1988d90>,
# ...
#  [Text(1.094361499650731, 0.11123357443777165, '2004'),
#   Text(1.0345168142548666, 0.3738648967527737, '2005'),
#   Text(0.770371664060214, 0.785192651018269, '2017'),
#   Text(0.290596432794885, 1.0609211625973383, '1989'),
#   Text(-0.07940013579162518, 1.0971306296135714, '1999'),
#   Text(-0.3503702208156666, 1.0427083524963159, '2013'),
#   Text(-0.5316928796204935, 0.9629655662384131, '1997'),
#   Text(-0.9554443826095745, 0.5450926817888946, '2006'),
#   Text(-1.0955002907727265, -0.09939372674808052, '2013'),
#   Text(-1.031311038109368, -0.38261931821822304, '2010'),
#   Text(-0.913820940311709, -0.6123163308681422, '2002'),
#   Text(-0.8200012238748795, -0.7332107424497407, '2005'),
#   Text(-0.6876252945715636, -0.8585868938350798, '2011'),
#   Text(-0.34451361167846484, -1.0446580164667574, '1985'),
#   Text(-0.0016715049770867397, -1.0999987300315903, '2017'),
#   Text(0.21931120549840064, -1.0779158571719958, '1990'),
# ...

# %%
time =np.arange(1,100,0.04)

# %%
time
# Out:
# array([ 1.  ,  1.04,  1.08, ..., 99.88, 99.92, 99.96])

# %%
amp=np.sin(time)

# %%
amp
# Out:
# array([ 0.84147098,  0.86240423,  0.88195781, ..., -0.60595428,
#        -0.57365808, -0.54044416])

# %%
pl.plot(time,amp)

# %%
pl.plot(a['Year of Release (Game)'],a['Units Sold (in millions)'])

# %%
sn.set(style='dark')

# %%
sn.distplot(a['Units Sold (in millions)'])
# Out:
# C:\Users\aedpu\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Units Sold (in millions)', ylabel='Density'>

# %%
a
# Out:
#                       Console                             Most Sold Game  \
# 0               PlayStation 2              Grand Theft Auto: San Andreas
# 1                 Nintendo DS                                 Nintendogs
# 2             Nintendo Switch                        Mario Kart 8 Deluxe
# 3                    Game Boy                                     Tetris
# 4              Game Boy Color    Pokemon Gold/Silver/Crystal (1999-2000)
# 5               PlayStation 4                         Grand Theft Auto V
# 6                 PlayStation                               Gran Turismo
# 7                         Wii                                 Wii Sports
# 8               PlayStation 3                         Grand Theft Auto V
# 9                    Xbox 360                         Kinect Adventures!
# 10           Game Boy Advance  Pokemon Ruby/Sapphire/Emerald (2002-2005)
# 11       PlayStation Portable     Grand Theft Auto: Liberty City Stories
# ...

# %%
sn.relplot(x='Console',y='Most Sold Game',data=a,col='Year of Release (Game)',hue="Units Sold (in millions)",kind="scatter")

# %%
sn.catplot(x='Year of Release (Game)',y='Units Sold (in millions)',kind='box',data=a)

# %%
sn.regplot(x='Year of Release (Game)',y='Units Sold (in millions)',data=a)
# Out:
# <AxesSubplot:xlabel='Year of Release (Game)', ylabel='Units Sold (in millions)'>

# %%
sn.pairplot(a)

# %%
sn.pairplot(a,hue='Units Sold (in millions)')

# %%
a
# Out:
#                       Console                             Most Sold Game  \
# 0               PlayStation 2              Grand Theft Auto: San Andreas
# 1                 Nintendo DS                                 Nintendogs
# 2             Nintendo Switch                        Mario Kart 8 Deluxe
# 3                    Game Boy                                     Tetris
# 4              Game Boy Color    Pokemon Gold/Silver/Crystal (1999-2000)
# 5               PlayStation 4                         Grand Theft Auto V
# 6                 PlayStation                               Gran Turismo
# 7                         Wii                                 Wii Sports
# 8               PlayStation 3                         Grand Theft Auto V
# 9                    Xbox 360                         Kinect Adventures!
# 10           Game Boy Advance  Pokemon Ruby/Sapphire/Emerald (2002-2005)
# 11       PlayStation Portable     Grand Theft Auto: Liberty City Stories
# ...

# %%
sn.pairplot(a,hue='Year of Release (Game)',palette='Set1')
